# %% [markdown]
# # Data Augmentation
#
# **Measures**:
# * **Val loss TRAIN**
# * **Test MSE**
# * **Test PSNR**
# * **Test SSIM**
# * **Cualitative: show reconstruction, normal and with augmentation**

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#DataAugmentation" data-toc-modified-id="DataAugmentation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>DataAugmentation</a></span><ul class="toc-item"><li><span><a href="#MSE-LOSS" data-toc-modified-id="MSE-LOSS-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>MSE LOSS</a></span><ul class="toc-item"><li><span><a href="#Quantitative" data-toc-modified-id="Quantitative-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Quantitative</a></span><ul class="toc-item"><li><span><a href="#Training-and-validation" data-toc-modified-id="Training-and-validation-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span>Training and validation</a></span></li><li><span><a href="#Test-set" data-toc-modified-id="Test-set-1.1.1.2"><span class="toc-item-num">1.1.1.2&nbsp;&nbsp;</span>Test set</a></span></li></ul></li><li><span><a href="#Qualitative-(How-it-reconstruct)---Only-in-Test" data-toc-modified-id="Qualitative-(How-it-reconstruct)---Only-in-Test-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Qualitative (How it reconstruct) - Only in Test</a></span><ul class="toc-item"><li><span><a href="#From-'clean'-images" data-toc-modified-id="From-'clean'-images-1.1.2.1"><span class="toc-item-num">1.1.2.1&nbsp;&nbsp;</span>From 'clean' images</a></span></li><li><span><a href="#From-corrupted-inputs" data-toc-modified-id="From-corrupted-inputs-1.1.2.2"><span class="toc-item-num">1.1.2.2&nbsp;&nbsp;</span>From corrupted inputs</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %%
import glob
import os

# %% [markdown]
# ## DataAugmentation

# %% [markdown]
# ### MSE LOSS
# #### Quantitative

# %% [markdown]
# * **PSNR**
# $$PSNR=10\times \log_{10}\frac{peakval^2}{MSE(x,y)}$$
# * **DSSIM**
# $$Structural Dissimilarity = DSSIM = \frac{1-SSIM(x,y)}{2}$$

# %% [markdown]
# ##### Training and validation

# %%
from create_test_report import TestMetricWrapper
model_folders = glob.glob('results/Data_Aug/*')
model_folders  = [mf for mf in model_folders if 'qualitative' not in mf]
TEST_img_PATH = '..'+os.path.sep+'IXI-T1'+os.path.sep+'PNG'+os.path.sep+'test_folder'+os.path.sep+'test'
test_img_files = glob.glob(TEST_img_PATH+os.path.sep+'*.png')

# %%
noaug_mse_test_metrics = TestMetricWrapper(model_folders,test_img_files)

# %%
_,_ = noaug_mse_test_metrics.get_training_df()
noaug_mse_test_metrics.get_min_validation_loss_df()
# Out:
#                                                   Val_loss  Epoch
# small_res_cae_MSE_full_pre_AUG_NoKReg_LRPlat  0.0001545063   56.0
# small_res_cae_MSE_full_pre_AUG_L2KReg_LRPlat  0.0003724099   38.0

# %%
noaug_mse_test_metrics.plot_val_loss(ylimit = 0.002, epochs=60)

# %% [markdown]
# ##### Test set

# %% [markdown]
# ***Method for getting metrics with keras_evaluate***: *WARN: Metric for models with L2reg add some variation due to L2 in loss*.
# ```python
# na_mse_kers_df = noaug_mse_test_metrics.get_keras_evaluation(return_type='df', verbose=2)
# na_mse_kers_df
# ```

# %%
na_mse_kers_df = noaug_mse_test_metrics.get_keras_evaluation(return_type='df', verbose=2)
na_mse_kers_df
# Out:
# small_res_cae_MSE_full_pre_AUG_L2KReg_LRPlat - 603/603 - 5s - loss: 3.6564e-04 - DSSIM: 0.0114 - PSNR: 35.2248
# small_res_cae_MSE_full_pre_AUG_NoKReg_LRPlat - 603/603 - 5s - loss: 1.5038e-04 - DSSIM: 0.0067 - PSNR: 38.5752
#                                                       loss         DSSIM  \
# small_res_cae_MSE_full_pre_AUG_L2KReg_LRPlat  0.0003656357  0.0114325024
# small_res_cae_MSE_full_pre_AUG_NoKReg_LRPlat  0.0001503847  0.0067493296
#
#                                                        PSNR
# small_res_cae_MSE_full_pre_AUG_L2KReg_LRPlat  35.2247695923
# small_res_cae_MSE_full_pre_AUG_NoKReg_LRPlat  38.5751533508

# %%
na_mse_custom_df = noaug_mse_test_metrics.get_custom_evaluation(return_type='df', verbose=True)
na_mse_custom_df.sort_values('mse_mean')
# Out:
# small_res_cae_MSE_full_pre_AUG_L2KReg_LRPlat - MSE: 3.24e-04+-1.25e-04 - DSSIM: 1.14e-02+-3.97e-03 - PSNR: 3.52e+01+-1.72e+00
#
# small_res_cae_MSE_full_pre_AUG_NoKReg_LRPlat - MSE: 1.50e-04+-6.33e-05 - DSSIM: 6.75e-03+-5.00e-03 - PSNR: 3.86e+01+-1.72e+00
#                                                   mse_mean       mse_std  \
# small_res_cae_MSE_full_pre_AUG_NoKReg_LRPlat  0.0001503846  0.0000632999
# small_res_cae_MSE_full_pre_AUG_L2KReg_LRPlat  0.0003237482  0.0001251418
#
#                                                 dssim_mean     dssim_std  \
# small_res_cae_MSE_full_pre_AUG_NoKReg_LRPlat  0.0067494712  0.0049995780
# small_res_cae_MSE_full_pre_AUG_L2KReg_LRPlat  0.0114326924  0.0039694123
#
#                                                   psnr_mean      psnr_std
# small_res_cae_MSE_full_pre_AUG_NoKReg_LRPlat  38.5751647949  1.7231842279
# small_res_cae_MSE_full_pre_AUG_L2KReg_LRPlat  35.2247657776  1.7153180838

# %%
no_aug_mse_plot = noaug_mse_test_metrics.plot_custom_metrics()

# %% [markdown]
# #### Qualitative (How it reconstruct) - Only in Test
# ##### From 'clean' images
# How the models reconstruct unmodified input MRIs?

# %%
clear_mris = noaug_mse_test_metrics.plot_images(id_images = [183,75], n_random=1, figsize=(20,15)) #id=800 is a good slice too
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000156E6469C18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000156E66199D8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# ##### From corrupted inputs

# %%
corrupted_mris, sel_images = noaug_mse_test_metrics.plot_corrupted_images(id_images = [183,75], n_random=0, figsize=(20,15))
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000156EFCDDE58> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000156EFE8C9D8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
corrupted_mris, sel_images = noaug_mse_test_metrics.plot_corrupted_images(id_images = [183,75,6], n_random=2, figsize=(20,15))
